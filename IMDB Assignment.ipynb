# %%
# Import Library

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
movies = pd.read_csv("C:/Users/Arun R/Desktop/Board_Infinity\Python\Assignments\IMDB/Movie+Assignment+Data.csv")

# %%
movies.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
movies.shape
# Out:
# (100, 62)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
movies.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %% [markdown]
# # Data Analysis Question to Answer
#
# > What is the business problem we are about to solve and what is my objective? Think?
#
# > What kind of analysis do i want to do and why? Think ?
#
# > what business impact can i create with my results? Think?
#
# > who are my end users or customers of my analysis ?

# %% [raw]
# 1. Create a new column called profit which contains the difference between the two columns: gross and budget

# %%
movies['Gross'] = movies['Gross'].floordiv(1000000)
movies['budget'] = movies['budget'].floordiv(1000000)

# %%
movies.head()
# Out:
#                    Title  title_year  budget  Gross      actor_1_name  \
# 0             La La Land        2016      30    151      Ryan Gosling
# 1               Zootopia        2016     150    341  Ginnifer Goodwin
# 2                   Lion        2016      12     51         Dev Patel
# 3                Arrival        2016      47    100         Amy Adams
# 4  Manchester by the Sea        2016       9     47     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# 0                 19000.0                     NaN  ...         7.9        7.8
# ...

# %%
# creating the new column name 'profit' by subtracting the 'budget' column from the 'gross' column

# hint : use insert method

# %% [raw]
# 2. Sort the dataframe using the profit column as reference
#
# # hint : Use Sort_values method

# %% [raw]
# 3. Extract the top ten profiting movies in descending order and store them in a new dataframe — top10
#
# # hint : use slicing techinque , loc or iloc
#
#  #now you will have top10 movies in terms of gross

# %% [raw]
# 4 .Plot a scatter or a joint plot between the columns budget and profit and write a few words on what you observed

# %%
# My observations 

# Write you observations here

# %% [raw]
# 5. Extract the movies with a negative profit and store them in a new dataframe — negative_profit

# %%
# call the new dataframe as negative_profit 

# when profit is < 0 

# identify bottom 5 profit movies

# %% [markdown]
# # Great!! We have done our first analysis…..

# %% [markdown]
# # What Next? Now, let’s say I want to find out the popular movies, by popular I mean they have a good public response.

# %%
movies['IMDb_rating'] # o to 10
# Out:
# 0     8.2
# 1     8.1
# 2     8.1
# 3     8.0
# 4     7.9
#      ...
# 95    8.5
# 96    7.9
# 97    8.1
# 98    7.7
# 99    7.6
# Name: IMDb_rating, Length: 100, dtype: float64

# %%
movies['MetaCritic']
# Out:
# 0     93.0
# 1     78.0
# 2     69.0
# 3     81.0
# 4     96.0
#       ...
# 95    88.0
# 96    94.0
# 97    81.0
# 98    65.0
# 99    65.0
# Name: MetaCritic, Length: 100, dtype: float64

# %%
# changing the scale of Metacritic  - divide metacritic by 10

# use the average of two rating (imdb + Metacritic).mean()

# %%
# Sort the Dataframe by descending on average rating column

# %% [raw]
# Now i want to dig a bit more to find out which are the movies that both Metacritic and IMDB are at a higher rating.
#
# Note: Remember not everything that you want will come from data, at time you need to be innovative enough and think like a data detective to come up with your own formulas which you think can strengthen the analysis. This is the teal power of an analyst
#
#
# Always think out of the box !!

# %%
# Finding the movies with metacritic-imdb rating <0.5 and also with the average rating of > 8

# universally_acclaimed movies

# getting top 5 movies

# %% [markdown]
# #### Great! We have created a new metric of our own.
#
# > Now, your production company is looking to make a blockbuster movie. There will primarily be three lead roles in your movie and the company wishes to cast the most popular actors for it
#
# > Since your manager doesn’t want to take a risk, he asked you to cast a trio that has already acted together in a movie before

# %% [markdown]
# # Find most popular trios - 1

# %% [raw]
# 1. Find the trios which have the most number of facebook likes combined. actor_1_facebook_likes, actor_2_facebook_likes, actor_3_facebook_likes
#
# 2. Find out the top 5 popular tios and output their names in a list

# %% [raw]
# [['Dev Patel', 'Nicole Kidman', 'Rooney Mara'],
#  ['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Casey Affleck', 'Michelle Williams ', 'Kyle Chandler'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt']]

# %% [raw]
# Lets take it to the next level
#
# Find the most popular Trios - 2
#
# in the previous we found most popular trios based on sum of facebook likes of all 3 actors. however now we will add a condition to check that all 3 actors are famous
#
# actor_1_facebook_likes: 70000
# actor_2_facebook_likes: 40000
# actor_3_facebook_likes: 50000
#
# Invalid combo is shown below
#
# actor_1_facebook_likes: 70000
# actor_2_facebook_likes: 30000
# actor_3_facebook_likes: 1000

# %%
indiv_popularity = movies[~((((movies['actor_1_facebook_likes'] < movies['actor_2_facebook_likes']/2) |
                              (movies['actor_1_facebook_likes'] < movies['actor_3_facebook_likes']/2))==True)
                             | (((movies['actor_2_facebook_likes'] < movies['actor_1_facebook_likes']/2) |
                                 (movies['actor_2_facebook_likes'] < movies['actor_3_facebook_likes']/2))==True)
                              | (((movies['actor_3_facebook_likes'] < movies['actor_1_facebook_likes']/2) |
                                 (movies['actor_2_facebook_likes'] < movies['actor_3_facebook_likes']/2))==True))]

# %%
# common elements of two dataframe


# number of trios satisfying the condition

# %% [raw]
# [['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt'],
#  ['Chris Hemsworth', 'Robert Downey Jr.', 'Scarlett Johansson'],
#  ['Robert Downey Jr.', 'Scarlett Johansson', 'Chris Evans']]

# %% [markdown]
# # Runtime Analysis

# %%
plt.figure(figsize=[8,4])
run = sns.distplot(movies['Runtime'])

# %% [markdown]
# # R rated movies
#
#     >Filter out movies that are R- rated
#     >Sort them by ‘CVotesU18’ in descending order
#     >Get the top 5

# %%
# similarly do it for other rating columns

# %% [markdown]
# # Demographic Analysis

# %% [raw]
# # use genre1, genre 2, genre3
#
# 1. First create a new datafram df_by_genre that contains genre_1, 2 & 3 and all columns related to cvotes/votea. around 47columns should be there in the dataframe
#
# 2. Now add a column called cnt to the data fram and initialize it to one
#
# 3. GRoup the data frame by genere1 and find summ of all the numerica columns such as cnt, cvote and vote columns and store it in df_byg1
#
# 4 . perform the same operation for genre 2 and genre 3
#
# # hint : use for loop and conditinal statement

# %%
# write your code here

# %% [raw]
# 5. Now that we have 3 dataframe performed by grouping over genre_1, 2 & 3 seperately. it is time combine them
#
# 6. The column cnt on aggregation has basically kept the track of the number of occurrences of each genre. Subset the genres that have at least 10 movies into a new dataframe genre_top10 based on the cnt column value.

# %% [raw]
# 7. take mean of all the columns
#
# 8. typecast the number of votes column to int

# %% [markdown]
# # Chart Time

# %%
# Boxplot sns.boxplot

x = year , y = Profit/ gross/Revenue


# year 2015 and 2009 clearly has datapoint with highest Revenue generating movie.

# %%
# Pair plot 

# sns.pairplot (data = df , vars = votes, revenue.gross, rating, runtime , average rating)


# Pairplot gives us the basic understanding on distribution of all the numerical column.

# %% [raw]
# # create a scatter plot for rev/gross and votes
#
# From the above scatter plot we observe that their are movies which has Higher Rating along with Higher Votes still Revenue is not up to the Mark. Year - 2012 (Django Unchained) Year - 2014 (Interstellar) Year - 2006 (The Prestige,The Departed)
#
# Let us extract more insights from the Table.... First split the Genre and Actor Table for more understandig !

# %% [raw]
# fig, ax1 = plt.subplots(figsize = (14,6))
#
# ax2 = ax1.twinx()
# ax1.bar(genre_temp['Genre1'],genre_temp['Revenue (Millions)'])
# ax2.plot(genre_temp['Genre1'],genre_temp['cnt'], 'o-', color="red" )
# ax1.set_xlabel('Genre')
# ax1.set_ylabel('Revenue', color='b')
# ax2.set_ylabel('No of Movies', color='r')
# plt.show()

# %% [raw]
# Genre - Action has maximum numbers of movies and which generates maximum Revenue compared to other Genre. But if we look at Drama and Comedy has on an average 150 nos of movies but generates very less revenue in comparision with other category of Genre and respective Revenues.
#
# Now we will look at the number of (movies) released in year..... YOY no of releases increaing linearly and year 2016 seems to have spike in no of relases. But Same growth is not observed for Revenue !

# %%
# by year how many movies are relased - use line chart for this

# %%
# by year revenue - use line chart for this
